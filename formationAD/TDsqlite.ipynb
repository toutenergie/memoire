# %%
# exo1
import sqlite3
nom=input('saisir le votre nom:')
email=input('saire votre email:')
numero=input('saisir le numero:')
section= input('votre section')
conn = sqlite3.connect('schools.db') 
cur = conn.cursor() 
# Insérer une ligne de données 
cur.execute("""create table if not exists students (id intiger autoincremente primary key, 
            name text,
            e_mail text,
            phone integer,
            section text)""")
cur.execute("insert into students(name,e_mail,phone,section) values (?,?,?,?)",(nom,
            email,numero,section))
cur.execute("""select* from students""")
# Engager l'opération 
#cur.execute("""delete from students""")
conn.commit() 
# Fermer la connexion 
conn.close()

# %%
# EXO4
conct=sqlite3.connect('mydatabase.db')
curs=conct.cursor()
curs.execute("""create table if not exists users
             (id INTIGER primary key  AUTOINCREMENT not null,
             usernames not null,
             password not null)""")
curs.execute("""insert into users(usernames,password) values(?,?)""", ("adf","adf123"))
cur.execute("""INSERT INTO userss(username, password) VALUES(?, ?)""", ("olivier", "password123"))
cur.execute("""INSERT INTO userss(username, password) VALUES(?, ?)""", ("john", "password456"))
cur.execute("""INSERT INTO userss(username, password) VALUES(?, ?)""", ("Marta", "password789"))
conct.commit()
conct.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # EXO4
# ----> 2 conct=sqlite3.connect('mydatabase.db')
#       3 curs=conct.cursor()
#       4 curs.execute("""create table if not exists users
#       5              (id INTIGER primary key  AUTOINCREMENT not null,
#       6              usernames not null,
#       7              password not null)""")
#
# NameError: name 'sqlite3' is not defined
